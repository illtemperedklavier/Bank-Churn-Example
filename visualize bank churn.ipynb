# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split

# %%
import numpy as np

# %%
df = pd.read_csv(r"D:\Data\predicting-churn-for-bank-customers\Churn_modelling_numeric.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  RowNumber  CreditScore  Gender  Age  Tenure    Balance  \
# 0           0          1          619       0   42       2       0.00
# 1           1          2          608       0   41       1   83807.86
# 2           2          3          502       0   42       8  159660.80
# 3           3          4          699       0   39       1       0.00
# 4           4          5          850       0   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  label  \
# 0              1          1               1        101348.88      1
# 1              1          0               1        112542.58      0
# 2              3          1               0        113931.57      1
# 3              2          0               0         93826.63      0
# 4              1          1               1         79084.10      0
#
#    country_codes  income_decile  age_quintile  credit_score
# 0              0              2             3             1
# 1              2              2             3             1
# 2              0              2             3             0
# 3              0              2             2             3
# 4              2              1             3             4

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'RowNumber', 'CreditScore', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'label', 'country_codes', 'income_decile',
#        'age_quintile', 'credit_score'],
#       dtype='object')

# %%
df = df.drop(['RowNumber', 'Unnamed: 0'], axis=1)

# %%
df.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619       0   42       2       0.00              1          1
# 1          608       0   41       1   83807.86              1          0
# 2          502       0   42       8  159660.80              3          1
# 3          699       0   39       1       0.00              2          0
# 4          850       0   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  label  country_codes  income_decile  \
# 0               1        101348.88      1              0              2
# 1               1        112542.58      0              2              2
# 2               0        113931.57      1              0              2
# 3               0         93826.63      0              0              2
# 4               1         79084.10      0              2              1
#
#    age_quintile  credit_score
# 0             3             1
# 1             3             1
# 2             3             0
# 3             2             3
# 4             3             4

# %%
df.columns
# Out:
# Index(['CreditScore', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
#        'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'label',
#        'country_codes', 'income_decile', 'age_quintile', 'credit_score'],
#       dtype='object')

# %%
plt.scatter(df['Balance'], df['NumOfProducts'],c=df['label'])
plt.xlabel('Balance')
plt.ylabel('NumOfProducts')
plt.colorbar()
plt.show()

# %%
plt.figure(1)
plt.xlabel('Balance')
plt.ylabel('NumOfProducts')
plt.scatter(df['Balance'], df['NumOfProducts'], c = df['label'])
plt.colorbar()



plt.figure(2)
plt.xlabel('Balance')
plt.ylabel('Tenure')
plt.scatter(df['Balance'], df['Tenure'], c = df['label'])
plt.colorbar()

# %% [raw]
# fig, axs = plt.subplots(2, 2)
# axs[0, 0].plot(x, y)
# axs[0, 0].set_title('Axis [0,0]')
# axs[0, 1].plot(x, y, 'tab:orange')
# axs[0, 1].set_title('Axis [0,1]')
# axs[1, 0].plot(x, -y, 'tab:green')
# axs[1, 0].set_title('Axis [1,0]')
# axs[1, 1].plot(x, -y, 'tab:red')
# axs[1, 1].set_title('Axis [1,1]')

# %%
X_values = df.drop('label', axis=1)

# %%
len(X_values.columns)
# Out:
# 13

# %%
cols = X_values.columns[:-3]
print(cols)
# Out:
# Index(['CreditScore', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts',
#        'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'country_codes'],
#       dtype='object')

# %%
colours = df['label'].values

# %%
fig, axs = plt.subplots(len(cols), len(cols), figsize=(20,20))
print(type(fig))
print(axs)

for i in range(len(cols)):
    for j in range(len(cols)):
        axs[i,j] = axs[i,j].scatter(df[cols[i]], df[cols[j]],c=colours, )
        axs[i,j].set_title(df[cols[i]],"vs ", ylabel=df[cols[j]])

#axs[1, 1].set_title('Axis [1,1]')
# Out:
# <class 'matplotlib.figure.Figure'>
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x00000249666F9F08>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496672F808>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496681B148>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496682E688>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966844B88>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496685E208>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496B9C3348>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966133EC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024967D1BEC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024967EB63C8>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000002496819B948>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024968142D88>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024967DFBB48>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496BA4A188>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496BA56E48>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496E37E248>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002495E71DD08>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024967FDEC48>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496E4E0148>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496D2B4B88>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000002496E431748>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024967D204C8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024967EDE248>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496818B588>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024968007148>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966B79FC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496BA5CD88>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024967D764C8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024967918588>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496B568488>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000002496A4F6AC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496E36F488>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024968168888>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496E3B8A88>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496A512C88>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024967EECEC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496E378108>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496D3272C8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496A532508>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496813E708>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000002496822C908>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249681C1B48>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249681E9CC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966879EC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496B5A8148>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496B5B9348>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496BA1F548>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496946F788>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496B61B908>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496B9C1B08>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024969458D48>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024968F75F88>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496B7261C8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496B7E5348>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496B8D9588>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249693D7788>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496922B988>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496917FBC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024969150D48>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024968FCCF48>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000002496B6D51C8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249691483C8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496B9025C8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496B90B788>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496B814988>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249668C2B88>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249668FCDC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966934FC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249669701C8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966CB8408>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024966CF3608>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966D2B808>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966D65A48>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966D9CBC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966DD6DC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966E0EFC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966E48248>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966E7C448>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966EB9648>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966EF3848>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024966F2CA48>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966F64C48>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966F9FE88>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024966FD5048>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496700F288>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249670484C8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249670816C8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249670BA8C8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249670F5B08>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496712DC88>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024967163E88>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496719D108>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249671D8308>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024967211508>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249672496C8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249672818C8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249672BDAC8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000249672F4D08>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002496732DF08>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000024967367108>]]

# %%
4+3
